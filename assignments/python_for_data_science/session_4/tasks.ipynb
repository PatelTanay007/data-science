# %% [markdown]
# # task 1

# %%
str="Flipkart-Sale2024"

a=str.lower()
a=a.replace("-"," ")

print(a)
# Out:
# flipkart sale2024

# %% [markdown]
# # task 2

# %%
product_name=" OnePlus Nord-CE 3 "

cln=product_name.strip()
cln=cln.upper()
cln=cln.replace("-",",")
print(cln)
# Out:
# ONEPLUS NORD,CE 3

# %% [markdown]
# # task 3

# %%
str="ZOMATO-FOOD-2024"
def split_product_code(product_code):
    return product_code.split("-")

final=split_product_code(str)
print(final)
# Out:
# ['ZOMATO', 'FOOD', '2024']

# %% [markdown]
# # task 4

# %%
str="Spotify_Premium_Offer"
ans=str[8:15:]
print(ans)
# Out:
# Premium

# %% [markdown]
# # task 5

# %%
product = 'Myntra Shirt'
price = 799.5
print(f"deal : {product} is available at Rs. {price} only!")
# Out:
# deal : Myntra Shirt is available at Rs. 799.5 only!
