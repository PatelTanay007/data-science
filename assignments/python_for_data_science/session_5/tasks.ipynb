# %% [markdown]
# # task 1

# %%
playlist_ids=[111,112,113,114,115]

for i in playlist_ids:
    print(i)
# Out:
# 111
# 112
# 113
# 114
# 115

# %% [markdown]
# # task 2

# %%
playlist_ids.append(116)
playlist_ids.extend([117])

for i in playlist_ids:
    print(i)
# Out:
# 111
# 112
# 113
# 114
# 115
# 116
# 117

# %% [markdown]
# # task 3

# %%
removed=playlist_ids.pop(0)

print(f"Removed playlist id is {removed}")

for i in playlist_ids:
    print(i)
# Out:
# Removed playlist id is 111
# 112
# 113
# 114
# 115
# 116
# 117

# %% [markdown]
# # task 4

# %%
insta_filters=("clarendon","gingham","moon","lark")

print(insta_filters)

# insta_filters.replace("clarendon","lightroom")

# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 3
#       1 insta_filters=("clarendon","gingham","moon","lark")
#       2 
# ----> 3 insta_filters.replace("clarendon","lightroom")

# AttributeError: 'tuple' object has no attribute 'replace'
# Out:
# ('clarendon', 'gingham', 'moon', 'lark')

# %% [markdown]
# # task 5

# %%
zomato_cart_prices=[100,200,300,400,500,600,700,800]
# zomato_cart_prices can change depend on the items added to the cart. So, we need to use list instade of tuple.

crick_team=("virat","rohit","dhoni","jadeja","bumrah")
# cricket team is fixed for a particular match. So, we can use tuple instead of list.
