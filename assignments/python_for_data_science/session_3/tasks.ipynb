# %% [markdown]
# # task 1

# %%
age=20
name="tanay"
hight=186.56
spotify=False
print(f"name:{name},{type(name)}")
print(f"age:{age},{type(age)}")
print(f"height:{hight},{type(hight)}")
print(f"spotify:{spotify},{type(spotify)}")
# Out:
# name:tanay,<class 'str'>
# age:20,<class 'int'>
# height:186.56,<class 'float'>
# spotify:False,<class 'bool'>

# %% [markdown]
# # task 2

# %%
prices=[65,199.99,125.25]
def total_cart_amount(prices):
    total = sum(prices)
    return total
result = total_cart_amount(prices)
print(result)
print(f"type of result:{type(result)}")
# Out:
# 390.24
# type of result:<class 'float'>

# %% [markdown]
# # taask 3

# %%
a=input("enter your cricket score:")
a=int(a)
if a>= 50:
    print("congretulations you have scored a half century")
else:
    print("keep going")
# Out:
# keep going

# %% [markdown]
# # task4

# %%
variable_is_premium = "True"
a = bool(variable_is_premium)
print(a,"",type(a))
# Out:
# True  <class 'bool'>
