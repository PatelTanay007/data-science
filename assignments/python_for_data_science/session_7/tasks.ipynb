# %% [markdown]
# # task 1

# %%
sp_time=int(input("enter your play time"))

if sp_time>120:
    print("You are a true music fan!")
else:
    print("keep listening!")
# Out:
# You are a true music fan!

# %% [markdown]
# # task 2

# %%
order_ammount=int(input("enter your zomato order ammount"))

if order_ammount>300:
    print("Eligible for free delivery")
else:
    print("Delivery charges apply'")
# Out:
# Eligible for free delivery

# %% [markdown]
# # task 3

# %%
total=int(input("enter your flipkart total ammount"))

if total>2000:
    print("You get a 10% discount")
elif total>1000:
    print("You get a 5% discount")
else:
    print("No discount")
# Out:
# No discount

# %% [markdown]
# # task 4

# %%
points = int(input("Enter your IPL fantasy team points: "))

if points > 500:
    if points > 800:
        print("Champion")
    else:
        print("Top Performer")
else:
    print("Keep Trying")
