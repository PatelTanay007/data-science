# %% [markdown]
# # task 1

# %%
songs = ['Shape Of You', 'Blinding Lights', 'Levitating', 'Senorita']

cleaned_songs = list(map(lambda song: song.lower(), songs))
print(cleaned_songs)
# Out:
# ['shape of you', 'blinding lights', 'levitating', 'senorita']

# %% [markdown]
# # task 2

# %%
ratings = [4.2, 3.8, 4.5, 2.9, 3.5]

top_ratings = list(filter(lambda rating: rating > 4.0, ratings))
print(top_ratings)

# %% [markdown]
# # task 3

# %%
from functools import reduce

cart = [499, 1299, 299, 799]

total = reduce(lambda x, y: x + y, cart)
print(total)
# Out:
# 2896

# %% [markdown]
# # task 4

# %%
def format_followers(num):
    if num >= 1_000_000:
        return f"{num / 1_000_000:.1f}M"
    elif num >= 1_000:
        return f"{num / 1_000:.1f}K"
    return str(num)

followers = [950, 1500, 25000, 1200000]

formatted_followers = list(map(format_followers, followers))

print(formatted_followers)
# Out:
# ['950', '1.5K', '25.0K', '1.2M']

# %% [markdown]
# # task 5

# %%
# List of IPL scores
scores = [101, 98, 120, 77, 88]

# Use a lambda function with filter() to keep only even scores
even_scores = list(filter(lambda score: score % 2 == 0, scores))

# Print the filtered list
print("Even IPL Scores:", even_scores)
# Out:
# Even IPL Scores: [98, 120, 88]
