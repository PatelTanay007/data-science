# %%
class Playlist:
    def __init__(self):
        self._songs = []

    def add_song(self, song):
        self._songs.append(song)


# Create a playlist
playlist = Playlist()

# Add 3 songs
playlist.add_song("Blinding Lights")
playlist.add_song("Starboy")
playlist.add_song("Save Your Tears")

# Print the playlist
print("Playlist:", playlist._songs)

# %%
class Product:
    def __init__(self, price):
        self._price = price

    def get_price(self):
        return self._price

    def set_price(self, price):
        self._price = price


# Create a product
product = Product(25000)

# Get the current price
print("Original Price: ₹", product.get_price())

# Update the price
product.set_price(22000)

# Get the updated price
print("Updated Price: ₹", product.get_price())

# %%
class Movie:
    def __init__(self, rating):
        self._rating = 0
        self.set_rating(rating)

    def get_rating(self):
        return self._rating

    def set_rating(self, rating):
        if 0 <= rating <= 10:
            self._rating = rating
        else:
            print("Error: Rating must be between 0 and 10.")


# Create a movie
movie = Movie(8.5)

# Get the rating
print("Movie Rating:", movie.get_rating())

# Try to set a valid rating
movie.set_rating(9.0)
print("Updated Rating:", movie.get_rating())

# Try to set an invalid rating
movie.set_rating(12)
print("Rating after invalid input:", movie.get_rating())

# %%
from abc import ABC, abstractmethod


class PaymentMethod(ABC):

    @abstractmethod
    def pay(self, amount):
        pass


class Paytm(PaymentMethod):
    def pay(self, amount):
        print(f"Paytm: Payment of ₹{amount} made successfully.")


class PhonePe(PaymentMethod):
    def pay(self, amount):
        print(f"PhonePe: Payment of ₹{amount} made successfully.")


# Create objects
paytm = Paytm()
phonepe = PhonePe()

# Make payments
paytm.pay(500)
phonepe.pay(750)
