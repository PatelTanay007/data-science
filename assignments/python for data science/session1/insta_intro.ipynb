# %%
print("my name is tanay and my favorite app is instagram")
# Out:
# my name is tanay and my favorite app is instagram

# %%
print("Welcome to Data Science with Python!")
# Out:
# Welcome to Data Science with Python!
