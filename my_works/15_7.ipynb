# %%
# dict - key value pairs
my_dict = {
    "name": "John",
    "age": 30,
    "city": "New York"      
}

# %%
people = {
    "name": ["Tanay Patel", "Rahul Sharma", "Priya Mehta"],
    "email": ["tanay@example.com", "rahul@example.com", "priya@example.com"],
    "number": ["9876543210", "9123456780", "9988776655"]
}


for key, value in people.items():
    print(f"{key}: {value}")
# Out:
# name: ['Tanay Patel', 'Rahul Sharma', 'Priya Mehta']
# email: ['tanay@example.com', 'rahul@example.com', 'priya@example.com']
# number: ['9876543210', '9123456780', '9988776655']

# %%
tops={"company":"tops",
      "cources" :["data_science","web_development","data_analytics"],
      "students":[22,54,27]
      }

tops["cources"].remove("data_science")
tops.pop("students")
tops.fromkeys(["faculty"])
tops["faculty"] = ["kaveni mem"]

print(tops)
# Out:
# {'company': 'tops', 'cources': ['web_development', 'data_analytics'], 'faculty': ['kaveni mem']}
