# %%
l=[2,3,4,5]
l1=[]

for i in l:
    l1.append(i*i)

l1
# Out:
# [4, 9, 16, 25]

# %%
l2=[i*i for i in l]
l2
# Out:
# [4, 9, 16, 25]

# %%
l3=[i for i in l if i%2==0]
l3

# %%
l=["nirav","tanay","het"]
l4=[i.upper() for i in l]
l4
# Out:
# ['NIRAV', 'TANAY', 'HET']

# %%
# lamda - anonymus function

# %%
def test(a,b):
    return a*b

test(4,5)
# Out:
# 20

# %%
b = lambda a,b : a*b

b(10,5)
# Out:
# 50

# %%
cel = lambda e : (e*9/5)+32
cel(45)
# Out:
# 113.0

# %%
great = lambda a,b : a if a>b else b

great(10,30)
# Out:
# 30

# %%
l = [2,3,4]

sq= lambda a : [i*i for i in a]

# sq(l)

#or

list(map(lambda x:x**2,l))
# Out:
# [4, 9, 16]

# %%
l1=[1,2,3,4,5,6]
l2=[1,2,3,4,5,6]

# %%
l=["nirav","tanay","het"]
list(map(lambda x:x.upper(),l))
# Out:
# ['NIRAV', 'TANAY', 'HET']

# %%
#reduce

# %%
from functools import reduce
i=[4,5,6,7,8,9]
reduce(lambda x,y:x+y,i)
# Out:
# 39

# %%
l = [12,34,56,27,38,88]
reduce(lambda x,y : x if x>y else y,l)
# Out:
# 88

# %%
#filter

# %%
list(filter(lambda x: x%2 !=0 ,l))
# Out:
# [27]

# %%
l=["nirav","tanay","het"]
list(filter(lambda x:len(x)>3 ,l ))
# Out:
# ['nirav', 'tanay']
