# %%
def demo():
    print("hello world")

demo()
# Out:
# hello world

# %%
# a=input("enter your name")
# b=input("enter your age")

def printmsg(msg,):
    print(f"your name is {msg}")

def printmsg1(name,age):
    print(f"your name is {name} and your age is {age}")


# printmsg(a)
# printmsg(a,b)


printmsg(input("enter your name"))

printmsg1(input("enter your name"),input("enter your age"))
# Out:
# your name is tanay
# your name is tanayu and your age is21

# %%
def mul(a,b):
    print(a*b)
    return(a*b)

print(mul(5,2)+100)
# Out:
# 10
# 110

# %%
def calc(price,rate):
    disc=(price*rate)/100
    final_price=price-disc

    return final_price

calc(1000,20)
# Out:
# 800.0

# %%
def enc(sal,increment):
    inc=(sal*increment)/100
    final_sal=sal+inc

    return final_sal

# print(enc(1000,20))
enc(1000,30)
# Out:
# 1300.0

# %% [markdown]
# # HW

# %%
li=[87,69,88,95,93,61,77,83]
def avg(l):
    val=sum(l)/len(l)
    return val

average=avg(li)

print(f"the average of the given list is {average}")
# Out:
# the average of the given list is 81.625

# %%
def max(a,b):
    if a>b:
        return a
    else:
        return b
    
largest=max(34,47)

print(f"the bigger number is {largest}")
# Out:
# the bigger number is 47

# %%
def student_details(name, course="Data Science"):
    print(f"{name} is student of {course}")

student_details("tanay")
# Out:
# tanay is student of Data Science

# %%
def calculate_total_sales(sales):
    return sum(sales)

li=[200,2500,1450,1700,4200,3000]

print(f"total sales is {calculate_total_sales(li)}")
# Out:
# total sales is 13050

# %%
def count_even(numbers):
    count=0
    for i in numbers:
        if i % 2 == 0 :
            count+=1
    return(count)
num = [1,2,4,3,5,6,7,8,9]

evens=count_even(num)

print(f"total number of even numbers is {evens}")
# Out:
# total number of even numbers is 4

# %%
def calculate_discount(price, rate=10) :
    disc=(price*rate)/100
    final_price=price-disc

    return final_price

print(calculate_discount(1000))
# Out:
# 900.0

# %%
l=[2,3,4,2,4,8,5,6,7,3,7,5,9,1]

def remove_dup(l):
    l=set(l)
    l=list(l)
    return(l)

nl= remove_dup(l)

print(nl)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
def sales_summary(sales):
    ts=sum(sales)
    avgs=ts/len(sales)
    highest=0
    for i in sales:
        if i>highest:
            highest=i
    return(ts,avgs,highest)

sales=[200,2500,1450,1700,4200,3000]

total,avs,high=sales_summary(sales)

print(f"the total value sales is {total},total avg is {avs}, highest sale is {high}")
# Out:
# the total value sales is 13050,total avg is 2175.0, highest sale is 4200

# %%
def calculate_bonus(salary):
    if salary > 50000:
        return salary * 0.10
    else:
        return salary * 0.05

print(calculate_bonus(60000))
# Out:
# 6000.0

# %%
def calculate_total_expense(expenses):
    return sum(expenses)

print(calculate_total_expense([250, 500, 750, 1000]))
# Out:
# 2500
