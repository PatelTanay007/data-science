# %%
l=[4,8,6,2,1]
a=sorted(l)
print(a)
# Out:
# [1, 2, 4, 6, 8]

# %%
students=["sahil","priyanshu","saurabh"]
name="tanay"
students.extend(name)

print(students)
# Out:
# ['sahil', 'priyanshu', 'saurabh', 't', 'a', 'n', 'a', 'y']

# %%
students.insert(0,"nirav")

print(students)
# Out:
# ['nirav', 'sahil', 'priyanshu', 'saurabh', 't', 'a', 'n', 'a', 'y']

# %%
students.remove("sahil")

print(students)
# Out:
# ['nirav', 'priyanshu', 'saurabh', 't', 'a', 'n', 'a', 'y']

# %%
tup=("nirav","tanay","sahil","priyanshu")
print(tup)
# Out:
# ('nirav', 'tanay', 'sahil', 'priyanshu')

# %%
(a,b)=(5,7)
print(a)
print(b)
# Out:
# 5
# 7

# %%
set1={15,7,13.7,"tanay","nirav",7,15}
print(set1)
# Out:
# {7, 'tanay', 'nirav', 13.7, 15}
