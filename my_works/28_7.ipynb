# %%
# module if i want to create a python file than i use ap.py and if i want to create a jupyter file than i have to create ap.ipynb
# module - it contains variables functions classes same in jupyter 
# if i want to reuse function in jupyter than we cant but in module we can

# %%
import app
app.add(4,8) + app.sub(8,6)
# Out:
# 14

# %%
# type of modules
# 1.built in module
# import json , import csv 

# 2 user defind
# app.py

# 3 3rd-party module
# libraries numpy panda 
# to install it (pip install (library))

# %%
# 1st medhod to import
# 2nd method
    # from math import sqrt
    #

# %%
# 1st medhod to import
import math
math.sqrt(25)
# Out:
# 5.0

# %%
# 2nd method
from math import sqrt
sqrt(25)
# Out:
# 5.0

# %%
# 3
import math as m 
m.pi
# Out:
# 3.141592653589793

# %%
# 4
from math import *
print(sqrt(25))
print(pi)
# Out:
# 5.0
# 3.141592653589793

# %%
from math import * 
floor(5.9)
# Out:
# 5

# %%
from math import * 
ceil(5.9)
# Out:
# 6

# %%
# os - operating system
import os
import datetime
datetime
# Out:
# <module 'datetime' from 'c:\\Users\\Admin\\AppData\\Local\\Python\\pythoncore-3.14-64\\Lib\\datetime.py'>

# %%
# packeges - collection of modules
