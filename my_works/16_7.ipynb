# %% [markdown]
# # conditions

# %%
a=input("enter your rank number")
a=int(a)
if a<35:
    print(f"your rank is {a} so you are selected")
else:
    print(f"rejected because your rank is {a} ")
# Out:
# rejected because your rank is {a}

# %%
a=input("enter your age")
a=int(a)
if a<18:
    print(f"you can not drive because your age is {a}")
else:
    print(f"your age is {a} so you can drive ")
# Out:
# your age is 21 so you can drive

# %%
marks =int(input("enter your marks"))

if marks>90:
    grade="A grade"
elif marks>80:
    grade="B grade"
elif marks>60:
    grade="C grade"
elif marks>40:
    grade="D grade"
else:
    grade="faill"

print(f"your exam status is : {grade}")
# Out:
# your exam status is : B grade

# %%
a=int(input("enter the value of a :"))
print(f"the value of a is {a}")
b=int(input("enter the value of b :"))
print(f"the value of b is {b}")
c=int(input("enter the value of c :"))
print(f"the value of c is {c}")

if a>b and a>c:
    print(f"a is greatest and its value is {a}")

elif b>a and b>c:
    print(f"b is greatest and its value is {b}")
else:
    print(f"c is greatest and its value is {c}")
# Out:
# b is greatest and its value is 22

# %%
a=int(input("enter the number"))

if a % 2 == 0 :
    print("the given number is even")
else:
    print("the given number is odd")
# Out:
# the given number is odd

# %%
bill=int(input("enter the ammount of your bill"))

finala=bill-(bill*0.20)


if bill>5000:
    final_ammount=bill-(bill*0.20)
elif bill>3000:
    final_ammount=bill-(bill*0.10)

print(f"your final ammount to pay is rs{final_ammount}")
# Out:
# 800.0

# %%
a=int(input("enter the number"))

if a>0:
    print("the number is possitive")
elif a==0:
    print("the number is zero")
else:
    print("the number is negative")
# Out:
# the number is zero

# %%
sales=int(input("enter your sales"))
attendance=int(input("enter your attendance"))

if sales>=100000 and attendance>=90:
    print("the employee gets a bonus")
else:
    print("employee will not get the bonus")

# %%
a=input("enter your age")
b=input("enter your country of citizenship")
a=int(a)
if a>=18 and b=="india":
    print(f"you can vote")
else:
    print(f"you can not vote ")
# Out:
# you can not vote
